# %%
import pandas as pd 
import numpy as np

# %%
df = {
    'Candidate_ID': range(101, 121),
    'City': ['Mumbai', 'Pune', 'Mumbai', 'Delhi', 'Pune', 'Delhi', 'Mumbai', 'Pune', 'Delhi', 'Mumbai',
             'Pune', 'Delhi', 'Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Pune', 'Delhi', 'Mumbai', 'Pune'],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', np.nan, 'Female',
               'Male', 'Female', 'Male', 'Male', 'Female', np.nan, 'Male', 'Female', 'Male', 'Female'],
    'Education_Level': ['Diploma', 'Bachelors', 'Masters', 'Bachelors', 'Diploma', 'Masters', 'Bachelors', 'Diploma', 'Masters', 'Bachelors',
                        'Diploma', 'Masters', 'Bachelors', 'Diploma', 'Masters', 'Bachelors', 'Diploma', 'Masters', 'Bachelors', 'Diploma'],
    'Experience_Years': [2, 5, 1, 10, 3, 8, np.nan, 4, 12, 6, 
                         2, 7, 5, 3, 9, 4, 1, 11, 6, np.nan],
    'Salary_Expectation': [30000, 50000, 60000, 90000, 0, 85000, 55000, 35000, 110000, 58000,
                           32000, 75000, 52000, 38000, 95000, 45000, 28000, 105000, 62000, 40000],
    'Placed': ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No',
               'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No']
}

data=pd.DataFrame(df)
data.head(4)
# Out:
#    Candidate_ID    City  Gender Education_Level  Experience_Years  \
# 0           101  Mumbai    Male         Diploma               2.0
# 1           102    Pune  Female       Bachelors               5.0
# 2           103  Mumbai  Female         Masters               1.0
# 3           104   Delhi    Male       Bachelors              10.0
#
#    Salary_Expectation Placed
# 0               30000    Yes
# 1               50000     No
# 2               60000    Yes
# 3               90000    Yes

# %%
data.isnull().sum()
# Out:
# Candidate_ID          0
# City                  0
# Gender                2
# Education_Level       0
# Experience_Years      2
# Salary_Expectation    0
# Placed                0
# dtype: int64

# %%
data.shape
# Out:
# (20, 7)

# %%
sam_data = data[["Gender"]]

# %%
data["Gender"]= data["Gender"].fillna(data["Gender"].mode()[0])
data["Experience_Years"] = data["Experience_Years"].fillna(data["Experience_Years"].mean)
data.isnull().sum()
# Out:
# Candidate_ID          0
# City                  0
# Gender                0
# Education_Level       0
# Experience_Years      0
# Salary_Expectation    0
# Placed                0
# dtype: int64

# %%
pd.get_dummies(sam_data)
# Out:
#     Gender_Female  Gender_Male
# 0           False         True
# 1            True        False
# 2            True        False
# 3           False         True
# 4            True        False
# 5           False         True
# 6           False         True
# 7            True        False
# 8           False        False
# 9            True        False
# 10          False         True
# 11           True        False
# 12          False         True
# 13          False         True
# 14           True        False
# 15          False        False
# 16          False         True
# 17           True        False
# 18          False         True
# 19           True        False

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder(drop="first",sparse_output=False)
ar =one.fit_transform(sam_data) 
data["encode_gender"] = ar[:,0] 
data.head(1)
# Out:
#    Candidate_ID    City Gender Education_Level Experience_Years  \
# 0           101  Mumbai   Male         Diploma              2.0
#
#    Salary_Expectation Placed  encode_gender
# 0               30000    Yes            1.0

# %%
# label encodeing

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
data["label_encode_education_level"]= lab.fit_transform(data["Education_Level"])
data.head(20)
# Out:
#     Candidate_ID    City  Gender Education_Level  \
# 0            101  Mumbai    Male         Diploma
# 1            102    Pune  Female       Bachelors
# 2            103  Mumbai  Female         Masters
# 3            104   Delhi    Male       Bachelors
# 4            105    Pune  Female         Diploma
# 5            106   Delhi    Male         Masters
# 6            107  Mumbai    Male       Bachelors
# 7            108    Pune  Female         Diploma
# 8            109   Delhi  Female         Masters
# 9            110  Mumbai  Female       Bachelors
# 10           111    Pune    Male         Diploma
# 11           112   Delhi  Female         Masters
# 12           113  Mumbai    Male       Bachelors
# 13           114    Pune    Male         Diploma
# 14           115   Delhi  Female         Masters
# 15           116  Mumbai  Female       Bachelors
# 16           117    Pune    Male         Diploma
# 17           118   Delhi  Female         Masters
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
ord = [["Diploma", "Bachelors", "Masters"]]
lab1 = OrdinalEncoder(categories=ord)
data[["ordinal_encode_educational_level"]]= lab1.fit_transform(data[["Education_Level"]])
data.head(2)
# Out:
#    Candidate_ID    City  Gender Education_Level Experience_Years  \
# 0           101  Mumbai    Male         Diploma              2.0
# 1           102    Pune  Female       Bachelors              5.0
#
#    Salary_Expectation Placed  encode_gender  label_encode_education_level  \
# 0               30000    Yes            1.0                             1
# 1               50000     No            0.0                             0
#
#    ordinal_encode_educational_level
# 0                               0.0
# 1                               1.0
